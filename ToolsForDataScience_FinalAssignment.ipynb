# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Apoorvi Mittal**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because I enjoy the process of uncovering insights from data,
# and learning information from data that we did not know of before.*

# %% [markdown]
# ### The code in the below cell (cell 5) divides the number of reported covid deaths by the number of reported covid cases in India as of April 17th, 2022

# %%
521751/43042097
# Out:
# 0.01212187686859216

# %% [markdown]
# ![Screenshot%20%282%29.png](attachment:Screenshot%20%282%29.png)
#
# The above image shows for India as of April 17th 2022:
#
# 1. The vaccination dose status.
# 2. The testing status
# 3. The cases across India
#
# -------------------------------------------------------------------------------------------------------------------------------------------
